# %% [markdown]
# <a href="https://colab.research.google.com/github/rnadesan1961/pydata-book/blob/1st-edition/TravelersCodingChallenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Revi Nadesan
# ###Travelers Coding Challenge

# %%
# import modules pandas and numpy
import pandas as pd
import numpy as np
# json file 
import json

# %%
# mount the drive for loading the data file 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load the JSON file

# %%
import json
from google.colab import files
# loading to Panda dataframe 
df1= pd.read_json('/content/drive/Shareddrives/YMCA/TravelersCodeChallenge/part-r-00000-ace4d84a-d8cb-4eaa-a377-9d3e8bbf73b2.json', lines=True)
df1.head(10)
# Out:
#                                    guid  ...                       FormCd
# 0  69012de7-10d4-4b13-940c-872e8cc4a0f0  ...  Companies_GUID_Company-tree
# 1  5ec089ca-beb6-42e4-9184-216a7fd95612  ...  Companies_GUID_Company-tree
#
# [2 rows x 11 columns]

# %%
df1.columns
# Out:
# Index(['guid', 'name', 'rating', 'industry', 'is_service_provider',
#        'rating_type', 'is_subscribed', 'children', 'EventTS', 'EventTypeCd',
#        'FormCd'],
#       dtype='object')

# %%
df_parent= df1[['guid', 'name', 'rating', 'industry', 'is_service_provider',
       'rating_type', 'is_subscribed']]

# df1.to_csv('/content/drive/Shareddrives/YMCA/TravelersCodeChallenge/Travelers.csv', index=False)

df_mergedata=df_parent
df_mergedata.head()
# Out:
#                                    guid  ... is_subscribed
# 0  69012de7-10d4-4b13-940c-872e8cc4a0f0  ...         False
# 1  5ec089ca-beb6-42e4-9184-216a7fd95612  ...          True
#
# [2 rows x 7 columns]

# %%
df_child0=df1.loc[0,'children']
df_child0=pd.DataFrame(df_child0)
df_child0.head(20)
df_mergedata= df_mergedata.append(df_child0)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child1=df_child0.loc[3,'children']
df_child1=pd.DataFrame(df_child1)
df_child1.head(10)
df_mergedata= df_mergedata.append(df_child1)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child2=df_child0.loc[4,'children']
df_child2=pd.DataFrame(df_child2)
df_child2.head(15)
df_mergedata= df_mergedata.append(df_child2)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child3=df_child0.loc[5,'children']
df_child3=pd.DataFrame(df_child3)
df_child3.head(10)
df_mergedata= df_mergedata.append(df_child3)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child4=df_child0.loc[13,'children']
df_child4=pd.DataFrame(df_child4)
df_child4.head(10)
df_mergedata= df_mergedata.append(df_child4)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child5=df_child2.loc[2,'children']
df_child5=pd.DataFrame(df_child5)
df_child5.head(20)
df_mergedata= df_mergedata.append(df_child5)
# df_mergedata.reset_index(inplace=True)
df_mergedata
# Out:
#                                     guid  ...                                           children
# 0   69012de7-10d4-4b13-940c-872e8cc4a0f0  ...                                                NaN
# 1   5ec089ca-beb6-42e4-9184-216a7fd95612  ...                                                NaN
# 0   28837c60-21e8-49d2-aa29-6ab1a69af529  ...                                                 []
# 1   adbbff76-3846-46f3-bdd8-f0c4206e6803  ...                                                 []
# 2   b159d957-ec00-480a-948a-fb690836442a  ...                                                 []
# 3   7585a01a-fa62-4c26-be3f-f8e82aa819e0  ...  [{'guid': '5c0ec5d1-f582-422b-8881-bdfada235ce...
# 4   06c8cb4d-d3e8-40a4-9be5-20886a453468  ...  [{'guid': '3b510573-53a7-45ba-b221-4051fd27420...
# 5   9d00093b-10f4-4675-b6a1-3153c52fd6bf  ...  [{'guid': '2a5d7b7b-18d8-4302-85d1-f1f53fc8a6a...
# 6   960b263d-6db7-49be-a673-a5fb596eccfd  ...                                                 []
# ...

# %%
df_child6=df_child2.loc[4,'children']
df_child6=pd.DataFrame(df_child6)
df_child6.head(20)
df_mergedata= df_mergedata.append(df_child6)
# df_mergedata.reset_index(inplace=True)
df_mergedata

# %%
df_child7=df_child3.loc[2,'children']
df_child7=pd.DataFrame(df_child7)
df_child7.head(10)
df_mergedata= df_mergedata.append(df_child7)
# df_mergedata.reset_index(inplace=True)
df_mergedata

# %%
df_child8=df_child4.loc[1,'children']
df_child8=pd.DataFrame(df_child8)
df_child8.head(10)
df_mergedata= df_mergedata.append(df_child8)
df_mergedata.reset_index(inplace=True)
df_mergedata.head(100)

# %%
# Export to CSV
df_mergedata.to_csv('/content/drive/Shareddrives/YMCA/TravelersCodeChallenge/TravelersParentChild.csv',index=True)

# %% [markdown]
# ##EDA
# ###Perform the below descriptive analysis;
# ####1.   Get only the maximum rating for an industry
# ####2.  Get the minimum rating of a child company for the parent company
# ####3. Transpose all the child companies as columns for a parent company

# %%
# 1.   Get only the maximum rating for an industry
# The max rating for each level (Parent, Child, GrandChild, GreatChild

df_MaxRatingByIndustry=df_mergedata.groupby('industry')['rating'].max()
df_MaxRatingByIndustry
# Out:
# industry
# Business Services    780
# Energy/Resources     710
# Engineering          760
# Finance              700
# Manufacturing        770
# Technology           760
# Name: rating, dtype: int64

# %%
df_mergedata.columns
# Out:
# Index(['index', 'guid', 'name', 'rating', 'industry', 'is_service_provider',
#        'rating_type', 'is_subscribed', 'children'],
#       dtype='object')

# %%
####2.  Get the minimum rating of a child company for the parent company
#2. df_MaxRatingByIndustry=df_mergedata.groupby('industry')['rating'].max()
df_MaxRatingByIndustry=df_mergedata.groupby('name')['rating'].min()
df_MaxRatingByIndustry

# %%
####3. Transpose all the child companies as columns for a parent company
df_mergedata
df_Non_K=df_mergedata.iloc[1] 
df_Non_K=pd.DataFrame(df_Non_K)
df_Non_K
df_Non_K= df_mergedata.loc[df_mergedata['name']== 'Huntington Bancshares, Inc.']
df_Non_K
# Out:
#    index                                  guid  ... is_subscribed  children
# 1      1  5ec089ca-beb6-42e4-9184-216a7fd95612  ...          True       NaN
#
# [1 rows x 9 columns]

# %%
df_K_data= df_mergedata.drop(1)
#df_K_data

# %%
df_K_data.drop(['index'], axis=1)
df_K_data

# %%
df_K_data.set_index('guid', inplace=True)
df_K_data.drop(['index'], axis=1)
df_K_data

# %%
# #df_K_data=df_K_data.reset_index(drop=True)
# df_K_data_new=df_K_data.set_index('guid', inplace=True)

# %%
df_k_data_pivot=df_K_data.transpose()
df_k_data_pivot

# %%
df_final = df_k_data_pivot.iloc[1:]
df_final
# Out:
# guid                69012de7-10d4-4b13-940c-872e8cc4a0f0  ... f5265a90-bf28-4a3a-9e1a-023ef1e22195
# name                                       KYOCERA Group  ...                     KYOCERA SENCO UK
# rating                                               490  ...                                  720
# industry                                   Manufacturing  ...                        Manufacturing
# is_service_provider                                False  ...                                False
# rating_type                                      CURATED  ...                              CURATED
# is_subscribed                                      False  ...                                False
# children                                             NaN  ...                                   []
#
# [7 rows x 57 columns]
